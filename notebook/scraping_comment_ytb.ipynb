# %%
from googleapiclient.discovery import build
import pandas as pd

# %%
def video_comments(id): # Fungsi tidak lagi memiliki parameter 'max_results'
    """
    Mengambil semua komentar dan balasannya dari sebuah video YouTube tanpa batas jumlah.

    Args:
        id (str): ID video YouTube.
        api_key (str): Kunci API YouTube Anda.

    Returns:
        list: List of lists yang berisi data komentar (publishedAt, authorDisplayName, textDisplay, likeCount, type).
    """
    all_comments = []
    yt = build('youtube', 'v3', developerKey=api_key)

    # Panggilan API awal. 'maxResults=100' adalah parameter API, bukan variabel Anda.
    # Ini menentukan jumlah item per halaman yang akan dikembalikan oleh YouTube API.
    video_response = yt.commentThreads().list(
        part='snippet,replies',
        videoId=id,
        maxResults=100 # Parameter API: mengambil maksimal 100 hasil per permintaan
    ).execute()

    # Loop akan berlanjut selama ada respons dan ada halaman komentar berikutnya
    while video_response:
        for item in video_response['items']:
            comment_data = item['snippet']['topLevelComment']['snippet']
            published = comment_data['publishedAt']
            user = comment_data['authorDisplayName']
            comment_text = comment_data['textDisplay']
            like_count = comment_data['likeCount']
            
            all_comments.append([published, user, comment_text, like_count, 'comment'])

            replies_data = item.get('replies', {}).get('comments', [])
            for reply in replies_data:
                reply_data = reply['snippet']
                reply_published = reply_data['publishedAt']
                reply_user = reply_data['authorDisplayName']
                reply_text = reply_data['textDisplay']
                reply_like_count = reply_data['likeCount']
                
                all_comments.append([reply_published, reply_user, reply_text, reply_like_count, 'reply'])
        
        # Pindah ke halaman berikutnya jika ada nextPageToken
        if 'nextPageToken' in video_response:
            video_response = yt.commentThreads().list(
                part='snippet,replies',
                videoId=id,
                pageToken=video_response['nextPageToken'],
                maxResults=100 # Parameter API: memastikan halaman berikutnya juga mengambil 100 hasil
            ).execute()
        else:
            # Jika tidak ada nextPageToken, berarti sudah mencapai akhir komentar
            break

    return all_comments

# %%
api_key = 'API KEY'

# https://www.youtube.com/watch?v=ORu80EfjEkg
video_id = 'ORu80EfjEkg'

comments = video_comments(video_id)

comments
# Out:
# [['2025-08-27T06:34:43Z',
#   '@joymaradona7695',
#   'Ketawa mu jelek pisan mas',
#   0,
#   'comment'],
#  ['2025-08-24T23:13:27Z',
#   '@untunggratis',
#   'Sebenarnya VO nya Okeh-okeh Aja, Yang Sangat Disayangkan Animasinya 😂',
#   0,
#   'comment'],
#  ['2025-08-24T11:07:08Z',
#   '@rezarahmaddhitya',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2440">40:40</a> unjuk tetong bejirr',
#   0,
#   'comment'],
#  ['2025-08-24T03:50:03Z',
#   '@kazutoai3940',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2395">39:55</a> bang jangankan 3 bulan, one Piece aja anime weekly/ mingguan aja bisa bikin yang lebih bagus, palingan kalo mau bikin eps special kaya zoro vs king atau Luffy vs kaido palingan libur 1,2 minggu atau gak bikin eps recap buat ngisi jadwal doang jir',
#   0,
#   'comment'],
#  ['2025-08-22T20:00:11Z',
#   '@lovendearest',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4199">1:09:59</a> bukan tiket gala premier sih. tapi gue liat twit orang dikasih tiket nonton gratis ni film, tiketnya kecil &amp; lecek bat kek kupon qurban idul adha. mana ada jg yg bikin GA nonton gratis, satu orang 5x nonton WKWKWKWK mau bikin trauma anak orang 🤣😭',
#   0,
#   'comment'],
#  ['2025-08-22T19:41:00Z',
#   '@lovendearest',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3570">59:30</a> ga, yang gue tangkep dari kata &quot;kualitas animasi ga jadi syarat utama film animasi&quot; tuh mksdnya lu ga harus bikin animasi 3d/2d yg detail buat dibikin jadi film. lu mau bikin animasi stickman, bentuk abstrak, blob bunder2, ato yg sejenis doodle pun juga bisa.<br><br>BUKAN LU ARTIIN SECARA HARFIAH asal ngambil asset sana sini, timpa2 ga jelas, dll buat bikin film yg tayang di BIOSKOP DONGGGGGGG, BAPAKKK.<br><br>mana visualnya ga dapet, plot/storyline-nya juga ngaco bgt. berasa lagi mimpi waktu demam di siang bolong.',
#   0,
#   'comment'],
#  ['2025-08-22T19:12:11Z',
#   '@lovendearest',
#   '&quot;film animasi pertama yg menceritakan tentang kemerdekaan&quot;<br><br>battle of surabaya ngamuk denger kalimat ini',
#   0,
#   'comment'],
#  ['2025-08-22T14:24:13Z',
#   '@DesiMoyyyyy',
#   'Yg bagian wawancara sm eksekutip produsernya itu... bawa2 &quot;gotong royong&quot; mulu pas budget disebut...<br>Itu artinya udah ngerti ya mksdnya... krn org yg gotong royongnya byk, maka &quot;porsi&quot;an bagian duitnya mengecil, jd jgn heran jadinya jelek ni film',
#   0,
#   'comment'],
#  ['2025-08-22T08:04:45Z',
#   '@rizky5961',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=564">9:24</a> sudah jelas itu karakter beli bukan bikin kreativitas 😂 animator boomers, pinter boong lgi',
#   0,
#   'comment'],
#  ['2025-08-22T07:38:14Z',
#   '@dmsvrgtma',
#   'BAGUSAN ANIMASI VERNALTA ANJENG 😂😂',
#   0,
#   'comment'],
#  ['2025-08-22T03:53:24Z',
#   '@ifalroket',
#   'Yang salah xx1, sogok langsung acc',
#   0,
#   'comment'],
#  ['2025-08-22T03:10:04Z',
#   '@jev3502',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=305">5:05</a> Itu kayanya yang desain poster emang copy paste dari chat WhatsApp bang 😂',
#   0,
#   'comment'],
#  ['2025-08-21T15:39:28Z',
#   '@agungtetap2789',
#   'Lebih bagus iklan sirup Marjan',
#   0,
#   'comment'],
#  ['2025-08-21T12:19:59Z',
#   '@manjumboenamsembilan2905',
#   'Voice Aktor cewe, hot bro mulus putih',
#   0,
#   'comment'],
#  ['2025-08-21T03:52:26Z',
#   '@allswan-b9o',
#   'evidence (barang bukti) dijadikan hadian panjat pinang 😂',
#   0,
#   'comment'],
#  ['2025-08-21T00:34:54Z',
#   '@breakingbrancheslyn',
#   'Lagipula, kenapa benderanya hilang duluan dan taunya disandera sebelum bocah-bocah itu ngelepasin burung?',
#   0,
#   'comment'],
#  ['2025-08-20T12:47:53Z',
#   '@Delnixgia',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1320">22:00</a> , nyari sampai DUGEON',
#   0,
#   'comment'],
#  ['2025-08-20T12:41:45Z',
#   '@temennyaanaknyasar2007',
#   'Pas pertama x liat posternya, udh yakin ni film cuman diyt doank. Eh rupanya tayang di bioskop😭 syok bgt Krn desain posternya kyk poster 90an🥹',
#   0,
#   'comment'],
#  ['2025-08-20T09:17:51Z',
#   '@ARRIVAL_6661',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=777">12:57</a> Uwu slayyy',
#   0,
#   'comment'],
#  ['2025-08-20T09:04:16Z',
#   '@RYNpro09',
#   'Film nya sekalas editan capcut versi gratisan 😭😭',
#   0,
#   'comment'],
#  ['2025-08-20T08:31:20Z',
#   '@AntBgs_5',
#   'Kasih rating rendah aja tu juga XXI yg gak profesional, krna udah nerima film jelek begini lewat orang dalam..<br>Penghancur Indonesia',
#   0,
#   'comment'],
#  ['2025-08-20T02:18:50Z',
#   '@vinkaarts',
#   'Bahkan pembuatan filmnya aja diKorup.<br>Semua aspek diKorup.<br>Negara surga bagi para KORUPTOR',
#   0,
#   'comment'],
#  ['2025-08-20T01:29:48Z',
#   '@triprasetyo9009',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4095">1:08:15</a> mngkn maksud bapaknya trangenerasi ya... mulutnya yg typo apa kupingku yg salah denger ini..',
#   0,
#   'comment'],
#  ['2025-08-19T19:15:42Z',
#   '@pscompressor7429',
#   'probowo sama gibran suka kok.. hahahaha.. patut nya perlu ada pungli atau tukang pakir liar dalam film ini untuk mengambarkan ini negara konoha yang merdeka.',
#   0,
#   'comment'],
#  ['2025-08-19T15:35:46Z',
#   '@sulpphy',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3509">58:29</a> chat yang ada di screenshot ini juga pake AI deh kayaknya. Mungkin nggak keseluruhan chatnya, tapi kebanyakan kalimat vibenya ChatGPT banget, apalagi bagian &quot;Dengan modal cuman segitu, saya nggak mau ribet minta bantuan sponsor--apalagi minta dana ke pemerintah!&quot;<br><br>Itu pake em dash dan ngikutin format &quot;not only X, but also Y&quot; yang sekarang udah lazim dianggap jadi indikator AI generated text',
#   0,
#   'comment'],
#  ['2025-08-19T13:05:32Z',
#   '@skp5990',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4082">1:08:02</a> suara mulyono tapi beda universe',
#   1,
#   'comment'],
#  ['2025-08-19T11:53:04Z',
#   '@winnieeprillia6058',
#   'Harusnya si bapak belajar dari animator nya Adit Sopo jarwo deh😅😂',
#   0,
#   'comment'],
#  ['2025-08-19T11:52:12Z',
#   '@skp5990',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3210">53:30</a> Anjir gw muak anjirrr , ciri khas boomer kalo kasih alasan2 pembelaan , asli muakkkk , padahal udah jelas2 style animmasi trailer dgn full ya sama lah njirrrrr',
#   0,
#   'comment'],
#  ['2025-08-19T11:45:39Z',
#   '@skp5990',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3050">50:50</a> anak bangsa dari manee ? anak tua bangke njir,',
#   1,
#   'comment'],
#  ['2025-08-19T10:07:02Z',
#   '@AnsharYunusXII',
#   'effortless bin mager type of film project, sorry to say',
#   0,
#   'comment'],
#  ['2025-08-19T10:06:26Z',
#   '@suzukikontoru3123',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3384">56:24</a> &quot;50thn Indonesia&quot; make ni org',
#   0,
#   'comment'],
#  ['2025-08-19T09:59:16Z',
#   '@skp5990',
#   'paparan dari guru gembul, malah ini film penuh simbol2 berbau komunis / PKI , serem anjirr. Cek aja yt nya',
#   1,
#   'comment'],
#  ['2025-08-19T08:05:40Z',
#   '@TutupMataBukaPikiran',
#   'Mungkin di indo pembodohan publik tdk terlalu dilihat penegak hukum. Mereka pada super sibuk semua, haha. Film yang mengacaukan rasa bangga dalam perayaan kemerdekaan RI.',
#   0,
#   'comment'],
#  ['2025-08-19T01:57:18Z',
#   '@hhhmmm_',
#   'bang lu harus liat review orang2 di IMDb',
#   0,
#   'comment'],
#  ['2025-08-19T01:17:08Z',
#   '@Kiritoo930',
#   'Cristopher Nolan bapak bapak tapi seleranya ga gitu😂',
#   0,
#   'comment'],
#  ['2025-08-19T00:57:41Z',
#   '@Kiritoo930',
#   'Ketawa pecah pas digudang😂bisa bisanya gudang desa ada senjata',
#   0,
#   'comment'],
#  ['2025-08-18T19:58:56Z',
#   '@sudanamrullipah3231',
#   'Wauu film 6M ini yang dibahas bang wkwkw',
#   0,
#   'comment'],
#  ['2025-08-18T17:45:56Z', '@lanmantul4730', 'Memalukan 😂😂😂😂', 0, 'comment'],
#  ['2025-08-18T15:02:48Z',
#   '@rprl4053',
#   'gw paling ngakak waktu ada gambar mba&#39;&#39; india😆',
#   0,
#   'comment'],
#  ['2025-08-18T14:29:23Z',
#   '@Ceritakiu',
#   'Beruntung banget 720 orang yg pernah nonton film ini. <br>Sekarang udah GK Ada lagi.',
#   0,
#   'comment'],
#  ['2025-08-18T14:11:14Z', '@ArizqhiAgung', 'kacawww', 0, 'comment'],
#  ['2025-08-18T13:55:05Z',
#   '@ayahrajendra839',
#   'males amat nonton film gitu kualitasmnya, mending nonton adit sopo jarwo...wkwkwkwkwkwkwk,<br>ga mengurangi rasa nasionalisme kok nek ga nonton film ini,,,',
#   0,
#   'comment'],
#  ['2025-08-18T11:49:34Z',
#   '@EditingForCapCut',
#   'desa mana yg menyimpan bendera kramat',
#   0,
#   'comment'],
#  ['2025-08-18T10:11:07Z',
#   '@wawansiswanto136',
#   'Tontonan menjijikan sekali,, sampah busuk gini masih aja dibahas,, buang aja ke TPA,, selesei,,,',
#   0,
#   'comment'],
#  ['2025-08-18T09:55:11Z',
#   '@ChandBr_',
#   'dulu di 2019 pernah ikut Project Pengadaan Material utk Pelabuhan, dan itu ane masuk ke Circle Bapak²...<br>emg dasarnya beda mindset kali ya,<br>banyak miss communication, banyak buang² waktu cuma buat kordinasi² ga jelas,<br>initinya :<br>- 90% kumpul² makan² ngopi²,<br>- 7% bicarain kerjaan, <br>- 3% kerja nyata (dan itu cuma yg muda² aja yg keliatan kerjanya).<br><br>karna ga tahan ane leave aja, 😅<br>gimana gak tahan, bicarain keuntungan ajah tapi ga ada action nya, yg muda doang yg action nya keliatan 😌',
#   0,
#   'comment'],
#  ['2025-08-18T07:55:20Z',
#   '@thisisajuju',
#   'bang, gua baru sadar. Lu mirip cahya (rrq monyet) pemain valorant-nya rrq wkwkw',
#   0,
#   'comment'],
#  ['2025-08-18T06:43:38Z',
#   '@amirasoemengkar',
#   'perfiki tuh sejenis LSM gitu?',
#   0,
#   'comment'],
#  ['2025-08-18T06:26:53Z',
#   '@ayrafedidasrul247',
#   'Itu KIPAS ANGIN (Blower) gede banget. Emang desa ini ada proyek besar apa??',
#   0,
#   'comment'],
#  ['2025-08-18T05:21:43Z',
#   '@kessinim',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1774">29:34</a> bahkan beberapa youtube chanel orang&quot; luar negeri pun sampe bahas ini juga, soalnya barusan lewat beberapa.... Malu gue bjir 😑 bukan gue yg bikin film, tapi gue ikut malu 😑',
#   0,
#   'comment'],
#  ['2025-08-18T04:42:41Z',
#   '@Satanica-666',
#   'Bila tonton jumbo.... sebanarnya banyak kelemahan pada jumbo tu.. tapi lebih teruk lagi merah putih... kata orang ,bukan kata dari kata saya.. hahaha... memang ridak layak di promosikan. Kapada  negara2x jiran .... betul2x tidak layak aama sekali... masih ketinggalan jauh ...',
#   0,
#   'comment'],
#  ['2025-08-18T02:40:48Z', '@pacegaming5135', 'suno itu', 0, 'comment'],
#  ['2025-08-18T02:04:25Z',
#   '@dennysetiawan553',
#   'mungkin film itu sarkas hasil kerjaan asn/pejabat konoha yg penting jadi aja urusan kualitas nomor ke sejuta dan dengan budget yg dimark up.. atau emang sengaja dibikin jelek banget biar jadi viral jalur hujatan netizen.. haahaaahaaaaa',
#   0,
#   'comment'],
#  ['2025-08-18T01:31:20Z',
#   '@Mr.Pasundan',
#   'Nah itu pa lurahnya yg ajak nonton 😂',
#   0,
#   'comment'],
#  ['2025-08-17T23:42:26Z',
#   '@ahmadafandi9668',
#   'Kataku mah bajak aja gak sih <br>Itu pun kalo ada yang mau😂',
#   0,
#   'comment'],
#  ['2025-08-17T18:28:57Z',
#   '@aqim_aja',
#   'Tiati bang ide lu ntar di pake buat part 2 nya😂',
#   0,
#   'comment'],
#  ['2025-08-17T18:24:34Z',
#   '@jiofficial9664',
#   'Beehenty jngn lanjyutttt nontonnn',
#   0,
#   'comment'],
#  ['2025-08-17T18:12:31Z',
#   '@Lyn_125',
#   'Bang, kok dakimakura lu bikin gua gak nyaman ya',
#   1,
#   'comment'],
#  ['2025-08-17T17:18:47Z',
#   '@Yourbe26',
#   'lebih manfaat liat tekotok dari pada liat animasi yang onoh',
#   0,
#   'comment'],
#  ['2025-08-17T16:17:26Z',
#   '@coronalady3051',
#   'GTA San Adreas rata kiri aja masih lebih bagus',
#   0,
#   'comment'],
#  ['2025-08-17T15:49:33Z',
#   '@ittamm3818',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1492">24:52</a> bnn saya harap wajib periksa para stafnya, maksudku, bagaimana bisa masuk ke bioskop dan sangat pede dengan film itu?😂',
#   0,
#   'comment'],
#  ['2025-08-17T15:11:29Z',
#   '@Jakartans1312',
#   'buat sekelas film bioskop ini termasuk ngasal, lebih masuk akal ini film di buat untuk jd bahan hujatan, buat mengalihkan berbagai isu2 yg besar,  mari coba ingat2 sebelum ini animasi tolol muncul ada isu apa 😂',
#   1,
#   'comment'],
#  ['2025-08-17T15:00:38Z',
#   '@arisardan9183',
#   'Ketika film animasi jumbo mulai mendaki gunung himalaya, maka merah putih ofa terjun kedalam palung mariana',
#   0,
#   'comment'],
#  ['2025-08-17T14:37:14Z',
#   '@risakuranboo',
#   'Paling takut, kalau one for all ini cuma buat pengalihan isu masalah2 politik konoha saat ini',
#   0,
#   'comment'],
#  ['2025-08-17T14:18:12Z',
#   '@SepotongPerkedel-YT',
#   'mending nonton film full AI yang pernah tayang dibioskop gila. apaan dah nih film kurang kerjaan seolah olah buat rame aja biar nutupin kebijakan kebijakan yang mau disahkan biar gak viral.',
#   0,
#   'comment'],
#  ['2025-08-17T14:12:17Z',
#   '@GMusic4YourLife',
#   'Minimal 10<br>Tahun penjara, maksimal hukuman pancung buat mereka semua yang trrlibat pembuatan animasi ini',
#   0,
#   'comment'],
#  ['2025-08-17T14:04:08Z',
#   '@AgusSudarmantoDan',
#   'Musik d awal ak ingat musik film Krisna warna biru',
#   0,
#   'comment'],
#  ['2025-08-17T10:52:49Z',
#   '@didanktwo',
#   'Jangan gitu bang, tinggal respect aja apa susahnya, kan karya orang beda2,selera orang juga beda2 gak mesti apa yg bukan selera lu itu gak bagus, animasi juga jenisnya macem2',
#   0,
#   'comment'],
#  ['2025-08-17T10:29:39Z',
#   '@zam-K.L-10',
#   'Merah Putih, Satu Untuk Time korupsi Aja. Di kata MONYET, marah2 ga terima. Faktanya yg ngisi suaranya MONYET semua. Smpai Burung pn di ubah suara, ganti suara🐒🐒 👍👍',
#   0,
#   'comment'],
#  ['2025-08-17T10:02:22Z',
#   '@asphyys',
#   'Banyak yg fomo review , ✋ absolute ass🤚',
#   0,
#   'comment'],
#  ['2025-08-17T06:45:00Z',
#   '@Bhie_Pahlevi',
#   'Film animasi yg sangat tidak layak rilis dimanapun.',
#   0,
#   'comment'],
#  ['2025-08-17T02:22:22Z',
#   '@lazyboy2192',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4352">1:12:32</a> Stay strong Bang Vino 💪',
#   0,
#   'comment'],
#  ['2025-08-17T01:57:19Z',
#   '@Chloeprice-h4e',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2769">46:09</a> Itu M4A1 Sama RK-62 (AK finlandia) Bang Yang Jadi Inspirasi Israel Bikin Galil<br><a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2793">46:33</a> Itu Beryl M762 Bang.... Varian AK Polandia Tapi parts masih bisa kanibal sama AK Asli Rusia',
#   0,
#   'comment'],
#  ['2025-08-16T23:38:13Z',
#   '@joesue3890',
#   'narasi &quot;feedback&quot; yang mereka bangun makin banyak menimbulkan banyak banyak pertanyaan &quot;mencurigakan&quot;. Entah apa yang mereka coba sembunyikan, mereka sepertinya berani membuka gerbang ruang &quot;diskusi, debat, pembuktian&quot; atau mereka sengaja alpa bahwa banyak tokoh film, tokoh animasi yang jauh lebih paham tapi seakan bisa di bodohi? MIRIS😢',
#   1,
#   'comment'],
#  ['2025-08-16T20:52:40Z',
#   '@Woffwooff1231',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2390">39:50</a> <br>💁\u200d♀️: kapan lagi ada animasi yang dibuat dalam 3…<br><br>😡: GAK! matane 3 bulan speedrunner kah?',
#   0,
#   'comment'],
#  ['2025-08-16T17:19:10Z',
#   '@hermancyril8161',
#   'Mending gua abisin duit 30-50ribu buat beli cemilan, minuman juga terus gua nonton breakdown ini ketimbang harus ke bioskoo, beli tiket film itu, dengan iming&quot; mendukung karya anak bangsa, nasionalis atau semacemnya atau beli tiket abis itu di dalem di rekam terus kontenin kaya anomali&quot; lainnya<br><br>btw musik di menit <a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=647">10:47</a> , <a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=862">14:22</a>, dan <a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=882">14:42</a> samaan',
#   0,
#   'comment'],
#  ['2025-08-16T16:16:51Z',
#   '@brodomasmu3938',
#   'Harusnya pakai boneka Unyil dkk saja, ngirit 😂',
#   0,
#   'comment'],
#  ['2025-08-16T15:42:09Z',
#   '@Aquartxy',
#   'ONE FOR SHIT !!!!<br>🤣🤣🤣🤣🤣<br><br>Gak pantes bawa bawa nama judul MERAH PUTIH',
#   0,
#   'comment'],
#  ['2025-08-16T15:40:32Z',
#   '@Aquartxy',
#   'PRODUSER FILM INI BILANG BAHWA BANYAK BIOSKOP MINTA AGAR DITAYANGKAN.......LOE PERCAYA ? 🤣🤣🤣🤣🤣🤣',
#   1,
#   'comment'],
#  ['2025-08-16T15:35:43Z',
#   '@abdulmuhaiminfakhri4130',
#   'BATALKAN ATAU BOIKOT 😂',
#   0,
#   'comment'],
#  ['2025-08-16T14:17:30Z',
#   '@santri_ngalong',
#   'Yang saya bingung kenapa yang maling bendera mempersyaratkan agar menangkap burung yang dilepas anak2 itu. <br><br>Bukannya burung itu dilepas pas lagi nyari bendera!? Terus tujuan awal dia mencuri bendera apa?<br><br>Harusnya bendera itu di curi karena anak2 itu melepaskan burung jadi kalo mau benderanya balikin tu burung. <br><br>BIKIN OTAK MAKIN .....😂😂😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-16T14:02:43Z',
#   '@Fake_Sailor99',
#   'J1vl4kan dr JUN4iD M1R4N,',
#   0,
#   'comment'],
#  ['2025-08-16T11:11:07Z',
#   '@rianaramadhanty2789',
#   'Serem banget sumpah animasinya',
#   0,
#   'comment'],
#  ['2025-08-16T10:44:26Z',
#   '@ryndrartowidyodo9671',
#   'Seperti karya anak kuliah',
#   0,
#   'comment'],
#  ['2025-08-16T10:35:03Z', '@zeddhiz', 'Jumbo ❎<br>Jem**t ✅', 0, 'comment'],
#  ['2025-08-16T10:18:30Z',
#   '@Fdl33',
#   'Gua liat bapak² baju item+topi jadi inget video bapak² yg ngaku jadi bagian IT Pemuda Pancasila',
#   0,
#   'comment'],
#  ['2025-08-16T08:18:55Z',
#   '@fajarsetiawan2965',
#   'FYI...itu maksut 80TH itu bukan eightyth tapi TH itu singkatan dari TAHUN 😅',
#   0,
#   'comment'],
#  ['2025-08-16T08:08:09Z',
#   '@HaameProject',
#   'One for all tAK KIRA BOKU NO HERO 😂, ternyata anomali<br>Ini animator nya kentongan itu kah ?',
#   0,
#   'comment'],
#  ['2025-08-16T08:05:23Z',
#   '@m1.01zahranormansyah4',
#   'sialan itu self dakimakura bkin ga fokus LMAO',
#   0,
#   'comment'],
#  ['2025-08-16T07:55:10Z',
#   '@Andikapratama-zo5xk',
#   'nontonnya harus Kualitas 10k biar jernih nih😂',
#   0,
#   'comment'],
#  ['2025-08-16T07:29:57Z', '@jeno-mbUl', '👍', 0, 'comment'],
#  ['2025-08-16T07:08:50Z',
#   '@ユキ-w4d',
#   'bang si billy klarif dia cuma VA aja trs dikambing hitamin gitu',
#   0,
#   'comment'],
#  ['2025-08-16T06:43:17Z',
#   '@dawikem3933',
#   'Tekotok<br>santoonTV<br>favorit dan layak masuk bioskop.',
#   0,
#   'comment'],
#  ['2025-08-16T06:29:53Z',
#   '@teamdoe4087',
#   'untung ni film gagal tayang, beeeh kalo jadi sama aja ni film kaya ngehina karya perfilman di indonesia yg di garap se kreatif mungkin. ibarat kata ni film kaya ngejatohin market value perfilman di indonesia. -menurut sapri 2025 (sapri = saya pribadi)',
#   0,
#   'comment'],
#  ['2025-08-16T06:27:58Z',
#   '@jokeinsidejoke9414',
#   'Msh bgus si unyil😅',
#   0,
#   'comment'],
#  ['2025-08-16T02:54:35Z',
#   '@widiputra8987',
#   'Anjir, mendingan anime yang dibikin BNI daripada ni film anomali cok 😂',
#   0,
#   'comment'],
#  ['2025-08-16T02:40:52Z',
#   '@yenettacandra-x1q',
#   'itu klarif animator juga tomlol, dia kerja dibayar sejuta (entah per project sejuta apa sebulan 1jt) masa iya dia 3 bulan tidur 2 jam sampe nerima2 aja? ini animator hidup di daerah mana? masih adakah pertalite 2rb an, nasi pecel 1.500?',
#   0,
#   'comment'],
#  ['2025-08-16T01:13:15Z',
#   '@na4bluu',
#   'PANTESANN, ORDAL COIII 😭🖐',
#   0,
#   'comment'],
#  ['2025-08-16T00:49:40Z',
#   '@rife_kun',
#   'apa sih anj animasi nitendo jadul masuk bioskop',
#   0,
#   'comment'],
#  ['2025-08-16T00:40:48Z',
#   '@Nickindo-cy1sv',
#   'Bang gw ngimpi lu main mobile legend',
#   0,
#   'comment'],
#  ['2025-08-15T23:38:22Z',
#   '@bushwalkerboy',
#   'Inilah yang dinamakan penghinaan terhadap negara, film sampah! 😂',
#   0,
#   'comment'],
#  ['2025-08-15T19:39:44Z',
#   '@B-BOW29',
#   'Klo disuruh pilih mau nonton film sinetron Indosiar atau Merah Putih one for all??😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-15T18:37:03Z',
#   '@shinhikari9279',
#   '&quot;lebih dari ini jika dibuat sungguh²&quot; ? Kimetsu aja tiap eps cuma butuh 1,2M, bpk dapat jatah berapa duit tuu?',
#   0,
#   'comment'],
#  ['2025-08-15T18:24:04Z',
#   '@riskapera',
#   'bang, aku loh nonton Kpop Demon Hunters di Netflix aja udah happy banget, film animasi yang bahkan ga rilos di bioskop tapi aku obsessed banget sama lagu-lagunya. Ketika Merah Putih trailernya keluar, aku pengen nangis sekaligus heran kok bisa dirilis di bioskop sih?😢',
#   0,
#   'comment'],
#  ['2025-08-15T17:47:47Z',
#   '@dimsumentaichi',
#   'Kek project film anak SMK yg baru belajar bikin animasi, kerasa banget abal-abalnya.',
#   0,
#   'comment'],
#  ['2025-08-15T16:54:21Z',
#   '@dianaulia2454',
#   'Mungkin ini dibuat emang buat dihina sama buat orang-orang yang pengen marah mencaci maki lewat ketikan. <br>Semangat teman-teman untuk merangkai kata-kata indah.',
#   0,
#   'comment'],
#  ['2025-08-15T16:51:58Z',
#   '@sarahonly1',
#   'gw cuma ngerasa film ini hanya buat pengalihan isu gw yakin si pembuat film ini tau kalo filmnya itu buruk ga layak tayang',
#   0,
#   'comment'],
#  ['2025-08-15T16:07:18Z',
#   '@tedipurnama4750',
#   'Mending nonton wonderland Indonesia, karya nya alvi rev.',
#   1,
#   'comment'],
#  ['2025-08-15T15:48:46Z',
#   '@tutor_mrbee',
#   'Tegal  kan  jawa tengah bang...,',
#   0,
#   'comment'],
#  ['2025-08-15T15:46:47Z',
#   '@sukajajan877',
#   'Berhenti jhangan lanjyuut',
#   0,
#   'comment'],
#  ['2025-08-15T15:29:26Z',
#   '@Pecintadota',
#   'akan ada &quot;aturan&quot; semua warga indonesia ber NIK indonesia wajib menonton Film Animasi &quot;terbaik sepanjang masa&quot; jika tidak ada yang menonton maka akan dikenakan denda sebesar 150.000.000/kepala yang tercantum pada Kartu Keluarga, dan/atau pidana penjara paling lama 6 bulan penjara dengan pasal Tidak Menghargai Hasil Karya Pemerintah,,,<br><br>semua denda yang dihasilkan akan diserahkan kepada Lembaga Perfilm-an Halu, <br><br><br>mending nonton Warkop DKI Kasino ( alm ) diseruduk becak masuk empang dah',
#   0,
#   'comment'],
#  ['2025-08-15T15:29:16Z',
#   '@nanwijanarko1969',
#   'Udah nonton Panji Tengkorak aja',
#   0,
#   'comment'],
#  ['2025-08-15T14:56:21Z',
#   '@dodykesumanegara415',
#   'Jangan lah anda menghina karya bapak2 bangsa. Mereka pasti sudah bekerja keras, sambil sarungan baca koran dan kopi item panas, memikirkan konsep film animasi super epic ini. Saya yakin mereka sudah berupaya menumpahkan ide dan gelas kopi itu ke komputer rendering Intel Core 2 Duo. Sudah banyak energi dan keringat yg mereka kuras, demi baju lembab dan bau, agar terlihat kerja. Cobalah hargai usaha mereka. Selera kalian mungkin beda dengan selera mereka yg kuno, primitif, dan purba. Biarkan mereka mengenang ini sebagai kebanggan karena telah mempermalukan Indonesia di kancah internasional. Jangan terkejut kalian, skor IMDB ini sangat membanggakan lho, masuk jajaran skor terburuk IMDB, bahkan jd rangking pertama, 1/10. Kerenkan. Belum pernah ada film blockbuster apalagi animasi peraih oscar yg pernah berada di posisi itu.',
#   0,
#   'comment'],
#  ['2025-08-15T14:26:33Z',
#   '@fikrimaulana7043',
#   'Bang wakilin nnton ya gue gak kuat',
#   0,
#   'comment'],
#  ['2025-08-15T14:17:09Z',
#   '@pyan_sfyn',
#   'Busett ngedit pakai PPT ini maa😢😢',
#   0,
#   'comment'],
#  ['2025-08-15T14:08:39Z',
#   '@rafidhianaufalherdyan498',
#   'alur ceritanya masih kalah sama &quot;antonim cilacap&quot;',
#   0,
#   'comment'],
#  ['2025-08-15T13:49:26Z',
#   '@yunajunareal',
#   'seperti lagu &quot;hawimau mlaya&quot; negara tetangga yg viral.. tapi ini versi film bukan lagu 😂',
#   0,
#   'comment'],
#  ['2025-08-15T13:41:07Z',
#   '@JudhaztKASKUS',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=230">3:50</a> posternya kayak dibikin pake power point njink',
#   0,
#   'comment'],
#  ['2025-08-15T13:01:35Z',
#   '@yuhonima',
#   'bantal nyai🥰<br>dakimakura andri💀',
#   0,
#   'comment'],
#  ['2025-08-15T12:21:43Z',
#   '@cheyenedjema9681',
#   'Masih aja ngeles pas diwawancara astaga 😭😭😭 emosi nontonnya <br>Kasihan bang Vino dikorbankan cuma untuk liat film dajjal itu 😔',
#   0,
#   'comment'],
#  ['2025-08-15T11:57:05Z',
#   '@Singularity369',
#   'Bahkan ceritanya template di gpt',
#   0,
#   'comment'],
#  ['2025-08-15T10:56:36Z',
#   '@DoyokTone',
#   'Ayo... Tertawa terus...',
#   0,
#   'comment'],
#  ['2025-08-15T10:40:07Z',
#   '@kiwkiwempukjerukiu-cc6sn',
#   'pertama nyampah maksud nya',
#   0,
#   'comment'],
#  ['2025-08-15T10:04:38Z', '@ChasteFuku', 'real maha dasyrat', 0, 'comment'],
#  ['2025-08-15T09:54:47Z',
#   '@annisahtanjung',
#   'Bang gua ngerti kali gimana rasanya jadi si BINTANG TAKARI. Gua pernah membimbing anak disekolah gua, anak SMK. Gua guru TATA BUSANA. anak gua disuruh jadi perwakilan kabupaten untuk lomba JA*****. Itu seminggu lagi waktu mau lomba, baru dikasih tau buat ikut lomba itu. Anak gua itu disuruh lomba TATA BUSANA, ada unsur angkat budaya yang ada di kabupaten kami. Nah, &#39;ORANG&#39; diKABUPATEN kami ini, yang mana nantinya yang bawa anak gua ke provinsi, belum ada ngasih ngasih uang untuk buat bajunya. H-2 lomba, baru dikasih uang untuk beli bahan baju lomba. H-2 itu pun udah sore bang, kabupaten kami ini juga cuma 1 yang jual toko bahan tekstil. Lu pikirlah bang, orang orang udah nyiapin baju sejak 3 bulan yang lalu. Eh kami, h-2 baru dapat uang untuk beli bahan baju. Akhirnya, gua bang yang jahitin baju anak gua tu. Harusnya anak gua itu yang jait, kan dia yang lomba. Gak tidur gua bang, jahitin baju anak gua untuk lomba. Banyak detail. Dan lo tau bang, apa kata &#39;ORANG&#39; KABUPATEN gua? <br>KALAU KALAH, YANG MALU BUKAN KABUPATEN AJA, SEKOLAH KALIAN NANTI BAKAL JELEK!<br><br>HELLLL NAH. BANG MEMANG ADA ORANG GILA GILA SEMACAM DI BALIK FILM INI BANG. <br><br>Gua ngerti banget rasanya jadi BINTANG TAKARI. RESPECT!! TIDUR CUMA 2 JAM!!',
#   3,
#   'comment'],
#  ['2025-08-15T09:46:12Z',
#   '@user-kqfsjhu',
#   'Setangkepku pas dengerin tanggapan mereka ngejiplak mereka bilang itu tuh referensi yang di modifikasi. Tapi menurutku itu sama aja maling karya orang terus kenapa harus dinormalisasi :(. Bayangan Maling aja Disini dibela²in. Apa kabar indonesia.',
#   0,
#   'comment'],
#  ['2025-08-15T09:13:19Z',
#   '@takingindikenal44',
#   'Pengalihan kah ?',
#   0,
#   'comment'],
#  ['2025-08-15T08:55:55Z',
#   '@aldantriwinata2500',
#   'Mesti di audit itu duit 6m sekian buat apa aja ,grafis bobrok character ngga jelas alur cerita juga gk masuk akal ,gini nih kalo proyek di kerjain ama bapak bapak gwoblok',
#   1,
#   'comment'],
#  ['2025-08-15T08:39:55Z',
#   '@bilych4091',
#   'bang itu yang belakang kasih bangku ngapa kasian nyengir Mulu sambil berdiri😂',
#   0,
#   'comment'],
#  ['2025-08-15T08:24:47Z',
#   '@meigishafardi4823',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2766">46:06</a> padahal preview assetnya bagus banget,eehhh sampe ke nih film ancur bener renderannya wkawkkw',
#   0,
#   'comment'],
#  ['2025-08-15T07:57:07Z',
#   '@Sir-Clippy',
#   'Salfok banget sama dakimakura Andri Lunatictwister 😔😔',
#   0,
#   'comment'],
#  ['2025-08-15T07:51:47Z',
#   '@liunardydarmawan5035',
#   'Org baru kenalan 3 bulan tp bela²in masukin film gnian ke bioskop aneh gk sih? Riskan gk sih,kalo jelek kan bs malu sendiri tuh org',
#   0,
#   'comment'],
#  ['2025-08-15T07:18:06Z',
#   '@tadbitmess',
#   'Ini lupa settingan RTX on gan...',
#   0,
#   'comment'],
#  ['2025-08-15T07:06:59Z',
#   '@fqomarumbois-bc9wg',
#   'Ceritanya bisa bagus kalau di ceritakan kalau bendera itu dibuat oleh pendiri desa dan sudah menjadi suatu budaya kalau setiap 17 agustus bendera itu yg dikibarkan hingga bendera itu dianggap pusaka bagi desa itu sendiri',
#   0,
#   'comment'],
#  ['2025-08-15T06:49:33Z',
#   '@okkarin',
#   'bahkan lebih bagus Dora the Explorer menurut gw, ini burik banget banget dan ga logic banget, bahkan kalo bilang buat anak2 masa ada AK-47 <a href="UCkszU2WH9gy1mb0dV-11UJg/hcMfY5_zAbbxvwKLooCoCA"></a><a href="UCkszU2WH9gy1mb0dV-11UJg/ygF1XpGUMMjk8gSDrI2wCx"></a>',
#   0,
#   'comment'],
#  ['2025-08-15T06:20:50Z', '@kebogiro614', '𝑓𝑖𝑙𝑚 𝐾0𝑁𝑇𝑂𝑂0𝐿', 0, 'comment'],
#  ['2025-08-15T06:20:13Z',
#   '@Momoi_Racing',
#   'Karakternya cocok buat untuk belajar animasi 3d di sekolah,jadi buatnya untuk tugas bae,bukan di perjualbelikan.',
#   0,
#   'comment'],
#  ['2025-08-15T06:16:52Z',
#   '@LintangKusuma-y9c',
#   'FILM MBAH BUKAN PELEM 🗿',
#   0,
#   'comment'],
#  ['2025-08-15T05:50:40Z',
#   '@skyzell5029',
#   'Kebiasaan para bapak-bapak di pemerintah, mau buat poster movie tapi gatel amat pingin namanya terkenal sampe-sampe di tulis tuh semua nama yang terlibat di poster depan',
#   0,
#   'comment'],
#  ['2025-08-15T05:44:21Z',
#   '@Xilonxs',
#   'Mungkin begini lore terkait desa dan benderanya yang hilang itu<br><br>Pada masa pendudukan Jepang dan Belanda di tahun 1945 - 1949, desa tersebut menjadi benteng terakhir saat pecahnya pemberontakan masyarakat dengan penjajah. Desa Tagi merencanakan girelya melawan pasukan Belanda yang memiliki kebun besar di dekat desa Tagi. Mereka memulai gerilya dengan membakar fasilitas untuk menghambat logistik Belanda di dekat desa itu. Akan tetapi pasukan Belanda tidak hanya diam saja ketika kawasannya diserang dan beberapa hari setelah gerilya tersebut, pasukan Belanda mulai melakukan serangan balasan ke desa sekitar kawasan Belanda dengan menyerang dan menyandera masyarakat desa Raya yang merupakan jalur logistik penting bagi pasukan gerilya dan desa lainnya yang kemudian menyerang desa Tagi. Desa Tagi menjadi benteng terakhir pertahanan melawan gempuran serangan Belanda yang berlangsung hingga 2 malam dan akhirnya desa Tagi mulai penyerangan balik untuk mengembalikan desa-desa yang sudah diambil oleh pasukan Belanda. Hingga pada akhirnya mereka berhasil mengusir pasukan Belanda dan mengibarkan bendera merah putih yang dimana warna merah itu menggunakan darah para pejuang dan mawar merah. Pada akhirnya setelah Indonesia dinyatakan merdeka, desa Tagi itupun sepakat untuk merubah namanya menjadi desa Merdeka (<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=521">8:41</a>).<br><br><br>Keknya gitu sih alasan kenapa di gudang desa ada senjata yang bekas perlawanan dan benderanya terlalu sakral untuk digantikan<br><br>Sekian dan terima kasih 🌷',
#   2,
#   'comment'],
#  ['2025-08-15T04:55:35Z',
#   '@annurraushania',
#   'Film Animasi Battle of Surabaya tahun 2015 jauhh lebih baikkk',
#   0,
#   'comment'],
#  ['2025-08-15T04:53:15Z',
#   '@sitinapisah7945',
#   'Gw sampe 4kali nonton jumbo karena temani keponakan 😅',
#   0,
#   'comment'],
#  ['2025-08-15T04:32:21Z',
#   '@theDyazzz',
#   'Film indie budget gotong royong, disuruh ngalahin jumbo.. tololnya...',
#   0,
#   'comment'],
#  ['2025-08-15T04:25:54Z',
#   '@adettewithyou',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4116">1:08:36</a> gw anak DKV bang, sekedar pengen cerita, orang orang seumuran mereka itu emang sukanya desain rame + nama mereka harus dicantumin, harus kelihatan paling gede, ga peduli penting atau nggak, pokoknya warna harus ngejreng kaya situl jud*',
#   1,
#   'comment'],
#  ['2025-08-15T04:16:56Z',
#   '@KingDeliver420',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=480">8:00</a> intro krisna',
#   0,
#   'comment'],
#  ['2025-08-15T04:08:49Z',
#   '@tiaranurulm3296',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3314">55:14</a> apalah di tanya siapa animatornya malah kemana2 anjirrrr asbun banget gak to the point 😂😂',
#   0,
#   'comment'],
#  ['2025-08-15T03:51:35Z',
#   '@firmanawd',
#   'Gue, setelah belajar Blender 1 bulan...',
#   0,
#   'comment'],
#  ['2025-08-15T03:35:39Z',
#   '@tiaranurulm3296',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1559">25:59</a> sinopsis nya aja pake ai bang 😂',
#   2,
#   'comment'],
#  ['2025-08-15T03:35:33Z',
#   '@brm5682',
#   'Terlepas dari apapun, gue heran kan udah ada chatgpt dari setahun yang lalu ya. kenapa mereka ga pake itu buat bantu bikinin ceritanya? emang mungkin gak bakal bagus tapi paling enggak, ngga akan sejelek ini..<br><br>Masalah dananya, gua gak ngerti dah. Kalau 6,7m gamungkin sejelek itu tapi gamungkin juga cuman pake dana sejuta. siapa juga yang mau nganimasiin ratusan scene animasi 70 menit tanpa dibayar? walaupun hasilnya jelek, semua itu butuh banyak effort sampe jadi film 70 menit<br><br>gak ngerti dah gue sama film ini, tapi gak percaya banget kalau ga ada duitnya. terlebih karena hasilnya ditayangkan secara komersil dibioskop. tapi kalau memang animasinya bukan diduitin pemrenta (yang gua juga ragu sih, siapa juga selain pemerenta yang mau duitin project kek gt) biarin ajalah ya, yang penting duit pajek kita gangalir kesitu',
#   0,
#   'comment'],
#  ['2025-08-15T03:34:16Z', '@kymori1101', 'MUAKKK BANGET MUAKKK', 0, 'comment'],
#  ['2025-08-15T03:10:33Z',
#   '@odyanderson4730',
#   'Da... Cancel aja kyk bisnis proposal',
#   0,
#   'comment'],
#  ['2025-08-15T02:56:10Z',
#   '@adityahermanto-b5d',
#   'LK21 bakal upload ga ya filmnya',
#   0,
#   'comment'],
#  ['2025-08-15T02:49:51Z',
#   '@HADI_LUPA_INGATAN',
#   'Gue mlh salut ama film ini... <br>Menggambarkan pemerintah konsisten gak haus pujian 😑😑😑😑',
#   0,
#   'comment'],
#  ['2025-08-15T02:45:56Z',
#   '@AdiArimbawa182',
#   'Bang, tolong bantal di belakang itu dikondisikan',
#   0,
#   'comment'],
#  ['2025-08-15T02:37:52Z',
#   '@Presidentxb',
#   'Pov bapak” pmerintahan yg maksa blajar otodidak dan bkin film animasi 😂 kyk animasi tugas anak smk jaman 2010😂',
#   0,
#   'comment'],
#  ['2025-08-15T02:28:33Z',
#   '@hoNEKOdayo',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3570">59:30</a> emeng ceritanya..... Dhlh',
#   0,
#   'comment'],
#  ['2025-08-15T02:21:45Z',
#   '@hoNEKOdayo',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2980">49:40</a> apresiasi jg bisa dalam bentuk kritik btw......',
#   0,
#   'comment'],
#  ['2025-08-15T02:04:08Z',
#   '@hoNEKOdayo',
#   'BTW..... Cuma mo ngingetin ges, klo ad hal goblok yg diba tiba trending, kemungkinan ada hal &quot;goblok&quot; yang disembunyiin',
#   0,
#   'comment'],
#  ['2025-08-15T01:59:44Z',
#   '@hoNEKOdayo',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1137">18:57</a> bang.... Emeng klo kebut semalam pernah merhatiin 🙂',
#   0,
#   'comment'],
#  ['2025-08-15T01:59:03Z',
#   '@hoNEKOdayo',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=926">15:26</a> actually ada premis yg cocok, kek<br>Ad hewan ato anak yg nyuri bendera, trus si anak anak luat si pencurinya, makanya dikejar tanpa mikir panjang (namanya anak2).<br><br>Nah karena udah terlanjur ngejer, mereka harus &quot;bertarung&quot; tuk dapet tuh bendera. Dan daripada &quot;disandra&quot;, kek.. terlalu dramatis, mending yah.... Gelut anak anak aja.. (gtu cara ngejelasinnya gimana 🙂)',
#   0,
#   'comment'],
#  ['2025-08-15T01:35:37Z',
#   '@SantiqueJob',
#   'prodak yg keluar dari mulut pemerintah pasti bakalan cacat dan menjijikan',
#   0,
#   'comment'],
#  ['2025-08-15T00:43:41Z',
#   '@StopJudayy',
#   '6,7M pinter banget nipunya wkwkw',
#   0,
#   'comment'],
#  ['2025-08-15T00:29:15Z',
#   '@kiaa1229',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1540">25:40</a> liat dah suku2 nya, &quot;medan, tegal, jawa tengah, makassar&quot; Wkwkwk tegal emang dmna anying, itu ngapa tegal ama jawa tengah seolah2 berdiri sendiri..',
#   2,
#   'comment'],
#  ['2025-08-14T22:43:39Z',
#   '@udinpetot4582',
#   'si billy suruh univnya cek ulang skiripsinya, kali aja jiplak kongkalikong ama dospem',
#   0,
#   'comment'],
#  ['2025-08-14T21:34:08Z',
#   '@xeno5418',
#   'Sutradara film ini kayaknya mikir Film Film jaman dulu yang grafiknya jelek tapi storynya enjoyable Dan bagus, tapi sutradara ini nangkepnya secara gamblang Dan lupa sekarang dia di tahun berapa😂😂',
#   0,
#   'comment'],
#  ['2025-08-14T21:11:17Z',
#   '@oyziparker117',
#   'rumornya juga film ini digadang gadang bakal masuk MCU dan akan menjadi jembatan yang akan menghubungkan antara seluruh universe di MCU dan berpengaruh besar terhadap multiverse saga ke depannya,film Avengers : Doomsday sendiri bakal ditunda penayangannya jika film ini gagal masuk ke MCU,karena akan sangat berpengaruh dan merusak tatanan multiverse Marvel jika film ini tidak menjadi bagian dari MCU.\r<br>Kevin Feige menegaskan bahwa film ini menjadi bagian dari MCU adalah suatu keharusan,jika tidak maka Multiverse yang mereka bangun selama bertahun tahun ini akan runtuh dan kemungkinan akan di reboot..dia juga mengatakan bahwa beberapa aktor dan aktris yang dikabarkan telah meninggalkan studio Marvel seperti scarlett johansson,zoe saldana,jeremy renner dan dave bautista telah menyatakan minat untuk kembali ke studio Marvel hanya jika mereka diizinkan untuk mengisi suara karakter di film ini walaupun tanpa dibayar.\r<br>&quot;mereka berlutut di bawah kaki saya memohon untuk kembali ke studio Marvel jika hal itu benar terjadi&quot; tegas Kevin Feige,dan sekarang Feige masih terus bolak balik Indonesia-Amerika untuk melobi agar film ini bisa menjadi bagian dari MCU &quot;saya berjanji akan melakukan semua yang bisa saya lakukan untuk seberapapun uang yang kami keluarkan,film ini HARUS menjadi bagian dari MCU&quot; kata Feige lagi..\r<br>\r<br>\r<br>\r<br>\r<br>\r<br>\r<br>TAPI MIMPI!!!\r<br>AK-47 SAMA M16 PINDAHIN DULU DARI BALAI DESA PAK!!<br>AAAHHHH!!!',
#   0,
#   'comment'],
#  ['2025-08-14T19:45:14Z',
#   '@Gejrotturkas',
#   'Anjir ada  senjata aka cuy 😂😂😂😂😂😂😂😂😂😂 di gudang sekolah ada senjata',
#   0,
#   'comment'],
#  ['2025-08-14T19:26:05Z',
#   '@bokunochannel84207',
#   'saya punya temen voice actor beberapa. ini gk ada post processingnya.',
#   0,
#   'comment'],
#  ['2025-08-14T19:02:44Z', '@Jidannugrahaa', '😂😂', 0, 'comment'],
#  ['2025-08-14T18:55:14Z',
#   '@meggiysaputra',
#   'Salfok sm buku karya dr. Andreas, SpKJ, kisah seorang pria yang melalui duka dengan mencuci piring😮',
#   0,
#   'comment'],
#  ['2025-08-14T18:49:07Z',
#   '@obeyyei',
#   'Biar bendera One Piece tidak di pakai lagi lah apalagi,',
#   0,
#   'comment'],
#  ['2025-08-14T17:42:09Z',
#   '@april2907',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4086">1:08:06</a> &quot; Kami harap setiap tgl 17 Agustus tayang Merah Putih OFA &quot; <br><br>Lah?? Film G30S PKI juga tayang tiap 30 September Pak',
#   1,
#   'comment'],
#  ['2025-08-14T17:38:06Z',
#   '@bambanghermansyah8790',
#   'parah, kacau bgt - asal2an',
#   0,
#   'comment'],
#  ['2025-08-14T17:24:00Z',
#   '@mellifluousyang381',
#   'Najis banget kan... sebuah penghinaan besar ya buat org² yg udah berjuang utk mengembangkan animasi indonesia.. 😢',
#   1,
#   'comment'],
#  ['2025-08-14T17:19:52Z',
#   '@AndreasFendy',
#   'Tegal ama Jateng beda?',
#   0,
#   'comment'],
#  ['2025-08-14T16:55:16Z',
#   '@aderahmat8018',
#   'Ada teori konspirasi komunis dari detail film',
#   0,
#   'comment'],
#  ['2025-08-14T15:41:20Z',
#   '@undetectedme7019',
#   'Ini film kek pengalihan isu banget, kek sengaja di rancang pemerintah terus proyeknya di serahkan ke sekumpulan Aki2',
#   0,
#   'comment'],
#  ['2025-08-14T15:35:41Z',
#   '@alphanzzsophyan1058',
#   'ada masker gas di gudangnya di paling atas',
#   0,
#   'comment'],
#  ['2025-08-14T15:18:31Z',
#   '@F44-n1l',
#   'Gak kebayang kalo movie si juki aja ada sekitar 100 orang pegawai dengan budgetnya sekitar 10 miliar. Lah movie ini bagaimana?',
#   0,
#   'comment'],
#  ['2025-08-14T15:02:03Z',
#   '@rizalrafli5254',
#   'Mending Dhot Design gak sih?',
#   0,
#   'comment'],
#  ['2025-08-14T14:58:09Z',
#   '@KhelyZeeg',
#   'bang Vino berjuang ya matannya nanti kalo sakit ke JEC jangan lupa',
#   1,
#   'comment'],
#  ['2025-08-14T14:50:03Z', '@IdonTea', 'Bikin mata katarak😭', 0, 'comment'],
#  ['2025-08-14T14:40:12Z',
#   '@AD-hb8zq',
#   'Kenapa ke barak militer? Kena hukum KDM karena melawan kebiasaan... 😅😅😅',
#   0,
#   'comment'],
#  ['2025-08-14T14:22:06Z',
#   '@Kimizuka_Zycko',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2920">48:40</a> ya taulah ya orang pemerintah kan pinter buat milih kata&quot; biar kedengeran bagus di telinga sesama boomer',
#   0,
#   'comment'],
#  ['2025-08-14T13:50:07Z',
#   '@untorod2308',
#   'Kenapa burung bersuara monyet adalah semata-mata untuk menghindari pembayaran royalti',
#   0,
#   'comment'],
#  ['2025-08-14T13:27:50Z',
#   '@agusvanani',
#   'Gimana, ada yg sudah nonton hari ini di bioskop? Mksdnya bener tayang nggak?',
#   0,
#   'comment'],
#  ['2025-08-14T13:19:49Z',
#   '@SiauwAdhie',
#   '[<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2078">34:38</a>] audiensi dark PERFIKI',
#   1,
#   'comment'],
#  ['2025-08-14T13:18:54Z',
#   '@MohammadSudirman-g8t',
#   'Minta maaf saya ada info. ada orang nonton channel ini film,merah putih, ya ini, serius ada ya, Sudah ada keluar filmnya.yaa 💯 , YouTube Ini nama channel naufal wi ya 😂😂😂',
#   1,
#   'comment'],
#  ['2025-08-14T13:14:23Z', '@oreopi', 'berhenti, jangan lyanjut', 0, 'comment'],
#  ['2025-08-14T13:06:56Z',
#   '@bangpacul9661',
#   'Soun nya ngikutin film Krisna prindavan 😂😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-14T12:57:29Z',
#   '@SiauwAdhie',
#   'btw itu satu anak bajunya sudah merah putih bisa buat gantiin bendera sementara',
#   0,
#   'comment'],
#  ['2025-08-14T12:56:28Z',
#   '@RahmatWarga62',
#   'apa kata vino bang,, 🤣',
#   0,
#   'comment'],
#  ['2025-08-14T12:38:12Z',
#   '@cancan000',
#   'Aku liat trailernya aja gak sanggup. Cringe parah.',
#   0,
#   'comment'],
#  ['2025-08-14T11:54:33Z',
#   '@natanfakhrymuhammad5594',
#   'ada yg ngerasa gasi kalo chat di <a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3507">58:27</a> tuh kayak hasil ai/chatgpt yg di salin tempel bgt, mulai dari cara penyampaian, tanda baca, bahkan penggunaan (—) di tengah kalimat. kalo yang sering pake chatgpt pasti ngeh dah',
#   1,
#   'comment'],
#  ['2025-08-14T11:39:34Z',
#   '@Nanoo555',
#   'Biaya 6,7m<br>100jt buat film yg karakternya beli<br>Selebihnya buat nyogok biar bisa masuk bioskoppp🤣🤣🤣',
#   1,
#   'comment'],
#  ['2025-08-14T11:38:52Z',
#   '@saberghoib4077',
#   'Bheta bhuka gudang benderanha hilang. Itu bukan logat timur tapi  orang Jawa pake logat timur. Coba cek kawan&quot; kalian yang medok lalu suruh pake kosa kata orang timur. Sumpah mirip😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-14T11:32:33Z',
#   '@felixbun1371',
#   'Hargailah karya seseorang dengan tepuk tangan. Tpi khusus yang ini boleh pakai ketawa kok',
#   0,
#   'comment'],
#  ['2025-08-14T11:31:09Z',
#   '@PackBagos',
#   'kiri pojok bawan itu sandman dari spiderman 3 bang awkwkwkwkwk',
#   0,
#   'comment'],
#  ['2025-08-14T11:23:59Z',
#   '@we_r_nana119',
#   'Udah tgl 14 tapi tiketnya ngga ada di bioskop kota Samarinda 😂',
#   0,
#   'comment'],
#  ['2025-08-14T11:18:20Z',
#   '@menotsundanot6164',
#   'Resolusi jaman MAJAPAHIT,,ga kebayang pecah pecah di taroh di layar bioskop 😅😅',
#   0,
#   'comment'],
#  ['2025-08-14T11:17:39Z',
#   '@Inunak1',
#   'siapapun yg bikin animasi ampas ini,ini adalah hal terhorror yg pernah gw liat<br>itu ya sama queen bee aja masih bagus itu dari pada film horror ini',
#   0,
#   'comment'],
#  ['2025-08-14T10:46:27Z',
#   '@AstaKT',
#   'pdhal mah klo emang niat awalnya dari rasa nationalisme dalam rangka kemerdekaan , filmnya bisa d upload aja ke youtube biar smua bisa nonton tanpa harus bayar, klo udh masuk ke bioskop mah udh bukan tentang rasa nasionalisme lagi tp itu udh bisnis yg cari untung, intinya mah mereka2 niatnya emang mau dpt untung banyak dengan modal minim dan gk peduliin kualitasnya wkwkwk.',
#   0,
#   'comment'],
#  ['2025-08-14T10:46:23Z',
#   '@kore4296',
#   'terimakasih bang scriptwriter TNM telah melakukan penumbalan 🥀',
#   0,
#   'comment'],
#  ['2025-08-14T10:43:35Z',
#   '@OvermindXBT',
#   'Sluruh tim produksi harus tes urin',
#   0,
#   'comment'],
#  ['2025-08-14T10:37:31Z',
#   '@HambaAmatiran11',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=367">6:07</a> Keknya mereka pake B.Inggris karena kalau pake bahasa Indonesia dikira produk dari channel TV SCTV😂',
#   0,
#   'comment'],
#  ['2025-08-14T10:34:20Z',
#   '@banganonim08',
#   'Alur ceritanya juga buatan chat gpt awowkwk',
#   0,
#   'comment'],
#  ['2025-08-14T10:11:23Z',
#   '@herucesarianto3082',
#   'ga jadi tayang kan, soalnya sya cek di xxi sma cgv gk ada',
#   0,
#   'comment'],
#  ['2025-08-14T10:06:23Z', '@miyaawcute', 'Capek ketawaa🤣🤣', 0, 'comment'],
#  ['2025-08-14T10:02:24Z',
#   '@KonteksBang',
#   'Fenomena timpa teks terbesar di abad ini. Mungkin lebih tepatnya timpa asset',
#   0,
#   'comment'],
#  ['2025-08-14T09:59:38Z',
#   '@fitmywan',
#   'Kok suuzon ya kalau trailer begini nnti filmnya lebih bagus :b 🥱😣',
#   0,
#   'comment'],
#  ['2025-08-14T09:52:31Z',
#   '@ghista7920',
#   'Ini sih bukan film anak bangsa tapi film anak boomer!😂',
#   1,
#   'comment'],
#  ['2025-08-14T09:46:12Z',
#   '@romeoj387',
#   'Kalo ngerjain project yg hanya mengandalkan kalangan &quot;teman/ordal&quot; , tanpa lewat tender, ya gitu hasilnya.. <br>Krn Gak bisa milih kualitas terbaik. <br><br>Padahal ribuan animator lokal yg kemampuan nya gak kalah dengan luar... <br>Wajar kalo mayoritas warga protes dgn film merahputih one for all ini..krn  bikin malu.  <br>Dari judul nya aja pake bahasa inggris, gak mencerminkan nasionalisme murni. <br>Intinya... JELEK... gak ada yg bisa dibanggakan, gak layak utk level nasional. <br>Kualitas video nya kasar kayak bocah belajaran.',
#   1,
#   'comment'],
#  ['2025-08-14T09:38:37Z',
#   '@septianifi1349',
#   'Tp mereka tau gasih sebelumnya ada jumbo, maksudku ga minderkah?',
#   0,
#   'comment'],
#  ['2025-08-14T23:47:04Z',
#   '@kaeltkottmir',
#   'Mereka tau, dan ya kyk lu bilang minder berat wkwk, makanya nih film gaje dibikin buat ngurangin gengsi org boomer ini',
#   0,
#   'reply'],
#  ['2025-08-14T09:34:56Z',
#   '@diviex9862',
#   'masih mendingan nonton dontol dengan kelakuannya drpd ini film wkwkkwkwkw',
#   0,
#   'comment'],
#  ['2025-08-14T09:32:26Z',
#   '@mkmdd-j2f',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=497">8:17</a> mungkin 80th itu 80 tahun bang, think poositive 😂',
#   0,
#   'comment'],
#  ['2025-08-14T09:14:34Z',
#   '@Rika-dt8vs',
#   'sumpah bnr kata eno benning, BANYAK BGT IKLANNYAAA APALAAHH',
#   0,
#   'comment'],
#  ['2025-08-14T09:14:20Z',
#   '@cegeishere',
#   'Heran sama alurnya, tiba tiba aja bendera hilang dari gudang desa masuk ke kuil yang entah nyembah demon apa 😂',
#   0,
#   'comment'],
#  ['2025-08-14T08:54:15Z', '@NadiaAsyifaAzahra123', '🎉🎉🎉🎉🎉', 0, 'comment'],
#  ['2025-08-14T08:43:08Z',
#   '@AndiDina-e6u',
#   'Berhenti ada kanyut',
#   0,
#   'comment'],
#  ['2025-08-14T08:14:13Z',
#   '@AnisFitria257',
#   'Masih bagus lakon studio yang udah 15 tahun lalu dr pada one for all ini',
#   0,
#   'comment'],
#  ['2025-08-14T08:07:51Z',
#   '@arsinomagia2252',
#   'Gw gak ngertu sih bang kenapa Kementrian Ekonomi Kreatif bisa support hal se Gak kreatif kayak gini',
#   0,
#   'comment'],
#  ['2025-08-14T08:07:10Z',
#   '@prayogitriwicaksono7917',
#   'Itu burung kakatua tapi dapet skin burung macaw ditambah dapet sound suara monyet 😂😂',
#   0,
#   'comment'],
#  ['2025-08-14T08:04:12Z',
#   '@gilgil2188',
#   'Itu film animasi kebangkitan PKI di indonesia, hati2',
#   0,
#   'comment'],
#  ['2025-08-14T08:02:56Z',
#   '@effakrisma',
#   'Dibahas 1 jam dong😂😂, isinya sangat mewakili opini gw',
#   0,
#   'comment'],
#  ['2025-08-14T07:51:29Z',
#   '@FauZhee',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2290">38:10</a> soal voice over aja, masih bagusan bang HebyMaulana yg suka dubbing parodi anime.',
#   1,
#   'comment'],
#  ['2025-08-14T07:42:03Z',
#   '@Siluman_Kodok26',
#   'Beta buka gudang (Dengan logat Jawa) 😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-14T07:35:56Z',
#   '@nathanaronlisardi7271',
#   'otakku sakit bang...',
#   0,
#   'comment'],
#  ['2025-08-14T07:28:11Z',
#   '@leody8269',
#   'Gak malu sama marjan 😂',
#   0,
#   'comment'],
#  ['2025-08-14T07:27:05Z',
#   '@radjamlbb',
#   'bikin sinopsis ga sama di animasi tim merah putih di animasibya tim merdeka 😅😅',
#   0,
#   'comment'],
#  ['2025-08-14T07:14:03Z',
#   '@keeempu',
#   'Produsernya kagak punya malu😮',
#   0,
#   'comment'],
#  ['2025-08-14T06:43:40Z',
#   '@wayansanjaya5457',
#   'jadi gini..itu m4 carbine adl utk re-enactment tentara nica..🤣',
#   0,
#   'comment'],
#  ['2025-08-14T06:42:46Z',
#   '@ponakanputin7944',
#   'Kekuatan orang dalem😂',
#   0,
#   'comment'],
#  ['2025-08-14T06:41:16Z',
#   '@luusdraw',
#   'Kebetulan tempatku kerja dulu pernah partnership sama Reallusion pas mereka rilis Cartoon animator 5). Jadi Reallusion itu kayak software ala ala blender gitu, buat animasi. Tapi mereka udah nyediakan banyak aset (walaupun berbayar tapi ofc nggak bisa buat komersil ya) <br><br>Pas liat ada animasi indo ini aku kayak familiar banget ლ\u2060(\u2060・\u2060﹏\u2060・\u2060ლ\u2060) pingin aku spill ke orang&quot; kantornya Reallusion rasanya',
#   7,
#   'comment'],
#  ['2025-08-18T10:25:23Z', '@Koppter42', 'Spill rasa kantornya :D', 0, 'reply'],
#  ['2025-08-14T06:34:16Z',
#   '@bijonearc3233',
#   'Melihat Trailer aja membuat saya jadi seperti ada di planet lain 😂.',
#   0,
#   'comment'],
#  ['2025-08-14T06:34:11Z',
#   '@ZivaFalisha777',
#   'Bang Vino tolong ditunggu updatenya dong 🙏🏻😂',
#   1,
#   'comment'],
#  ['2025-08-14T06:33:16Z',
#   '@EdoKondomlegit-w7j9r',
#   'TARIKBOS bukan cuma situs, tapi ladang cuan sejati!<br>Bener-bener site paling mantap! Respect buat TARIKBOS 💯',
#   0,
#   'comment'],
#  ['2025-08-14T06:32:13Z',
#   '@dhimaspratama367',
#   'Aib indonesia: film merah putih one for all',
#   1,
#   'comment'],
#  ['2025-08-14T06:31:34Z',
#   '@empathytobacco2008',
# ...
#   0,
#   'comment'],
#  ['2025-08-12T11:47:34Z',
#   '@zetto3902',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1003">16:43</a>  viewsnya bakal bnyk di yutub bg😂 banyak bot',
#   0,
#   'comment'],
#  ['2025-08-12T11:47:13Z',
#   '@misheyla783',
#   'Adri, gue mo jujur bgt, kalo gue lagi ujian essai pas gue SD dan gue gabisa jawab, gue bener2 cmn ngejawab 7 kata &quot;MERDEKA&quot; KURANG NASIONALIS APA GUE COKK WKWK.<br><br>&#39;Keterpanggilan sbg anak bangsa, apa yg hendak(?) diberikan kepada bangsa dan negara&#39; &gt;&gt; Harus bgt bikin karya tema propaganda yg mereka maksut dan selalu tema 17an. <br><br>Haduuuh, kasian bgt ke pekerja2 yg kerja membangun infrastruktur, orang pencetus Indomie, yg bikin clothingan lokal, yg bikin animasi sebagus Jumbo, JUki, dll, GA DIANGGEP KALIAN GESSS, KALIAN BLM BERKONTRIBUSI UNTUK NEGARA OMAYGAAAT. <br><br>Gue kuliah lulusan jurusan animasi, gue pernah bikin trailer dan yg pasti sperti yg lu blg dri, di trailer itu ga lgsg nunjukin ketauan ceritanya kek mana, terus yg pasti harus bisa menjanjikan juga, lah ini menjanjikan ti mana? <br><br>VINO, SEMANGAT VINO, moga selamet mata luuu ya, stay safe 🤣👁👁👍👍<br>Gue emg ga sempet buat ke bioskop + ga kuat juga euy.',
#   0,
#   'comment'],
#  ['2025-08-12T11:46:48Z',
#   '@Killdopamine_official',
#   'Jumbo (karya anak bangsa)<br>Merah putih one for all (karya elit bangsa) yg mau di anggap keren juga',
#   0,
#   'comment'],
#  ['2025-08-12T11:46:41Z',
#   '@dinarta2888',
#   'itu trailer pertamanya udah ngerangkum keseluruhan isi film🤣',
#   0,
#   'comment'],
#  ['2025-08-12T11:46:37Z',
#   '@Zennnnnz',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=680">11:20</a> gambaran singkat Mamat gun shop😂',
#   0,
#   'comment'],
#  ['2025-08-12T11:45:58Z',
#   '@rudyzatarra',
#   'Film ini cocok untuk menghukum anak yg bandel dan nilai nya jelek,<br>Anak q jg gt , kalau nilai nya jelek dan bandel di sekolah akan q ajak Dy nonton ni film di bioskop di bangku barisan depan biar g bandel lg di sekolah dan semangat untuk belajar biar nilainya g jelek,<br>Akhirnya anakq seminggu ini makin semangat belajarnya',
#   1,
#   'comment'],
#  ['2025-08-12T11:45:01Z',
#   '@KoNaway_Insight',
#   'Boomer boomer ini mending turu aj dah',
#   1,
#   'comment'],
#  ['2025-08-12T11:44:19Z',
#   '@jositjhai6269',
#   'Ngakak nonton reaction nya 🤣🤣🤣',
#   0,
#   'comment'],
#  ['2025-08-12T11:43:55Z',
#   '@Direct-Handler',
#   'Berhenti, jyangan lanjyut 💅🫦✨',
#   0,
#   'comment'],
#  ['2025-08-12T11:42:57Z',
#   '@yogisambodo',
#   'jadi kangen wonderland indonesia sih,....<br>lebih menunggu itu daripada ini hahahaha',
#   0,
#   'comment'],
#  ['2025-08-12T11:42:35Z',
#   '@kimjungmi4502',
#   'Keliatan kayak filter emak2 di ig 😂😂😂😂 editan kata2 quote 80an 😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-12T11:42:35Z',
#   '@rtdiiansyah',
#   'wareg gw jir wkwkwkkwk',
#   0,
#   'comment'],
#  ['2025-08-12T11:41:33Z',
#   '@lazycatmuse1418',
#   'Njir... yang bikin animasi udah gak niat, bokis lagi....',
#   0,
#   'comment'],
#  ['2025-08-12T11:41:20Z',
#   '@lev-k9j',
#   'gila keren banget kimi no nawa lewat 😂😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-12T11:40:50Z',
#   '@ikhwanussofa2965',
#   'Mending kembali kegudang desa ambil m4 langsung tembak itu semua penjahatnya lalu tinggal ambil benderanya',
#   0,
#   'comment'],
#  ['2025-08-12T11:40:30Z',
#   '@OctaviusRmdhn',
#   'gua lebih setuju kalo iklan marjan yang masuk bioskop',
#   0,
#   'comment'],
#  ['2025-08-12T11:40:03Z',
#   '@harism.a5910',
#   'Yg gw liat film ini isinya : Sekelompok boomer dgn ego dan kolotnya berkolaborasi dgn animator ego dan sombong dan ngebuang profesionalisme, plus kekuatan orang dalam. Yg mereka banggain cuma &quot;tema kebangsaan&quot; kn? Knp lu dgn dana 6,7M (katanya) ga bikin film anak real live aja sii, bisa jd kyk petualangan sherina tinggal matengin dan cari scriptwriter bagus. Kalopun misal modalnya kecil, ya knp lu berani bikin film jelek, ngasal, yg cuma jd aib bangsa. Punten, apapun klarifikasinya ga ada yg bisa dibenarkan, ini perkara kualitas dibalik orang&quot; yg ga sadar diri!',
#   0,
#   'comment'],
#  ['2025-08-12T11:39:42Z',
#   '@docHawk-de5uo',
#   'waktu produksi aslinya pasti emang cuman 3 bulan. pas diwawancara tv one narasumbernya bilang sendiri  produksi keselurhannya 1 tahun dan post produksinya 3 bulan, nah dia bilang sendiri post produksinya itu isinya buat bikin animasi. nahh sekarang kira kira deh 9 bulan itu ngapain aja wkwk, toh ide cerita dan proses animasinya dilakuin sama mas bintang wkwkw',
#   0,
#   'comment'],
#  ['2025-08-12T11:39:39Z',
#   '@LuvyByte',
#   'new info, ada yang “ngebela” film ini dengan embel-embel “kita dukung demi menuju golden era animasi indonesia”. so yeah, we’re totally cooked brother',
#   0,
#   'comment'],
#  ['2025-08-12T11:39:28Z',
#   '@MadeBhasvdewa',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4265">1:11:05</a><br><br>Coba deh liat capture komentar ketiga dr atas. Kalian pasti familiar dgn tata kalimat itu kan??<br>Komen template njir. Gue curiga itu yg komen lagi sarkas tp malah dicapture sm adminnya 😂😂😂',
#   2,
#   'comment'],
#  ['2025-08-12T11:39:06Z',
#   '@dinarta2888',
#   'gw kalo jadi presiden atau pemerintah yang &quot;punya semangat nasionalisme tinggi&quot; sih marah ya kalo ada film yang mempermainkan hari kemerdekaan',
#   3,
#   'comment'],
#  ['2025-08-12T11:37:46Z',
#   '@Long-The-PERMANENCE',
#   'Novel gua bahkan lebih baik daripada ini😅😅😅',
#   0,
#   'comment'],
#  ['2025-08-12T11:37:34Z',
#   '@noname7154',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1237">20:37</a> 😱😱😱😱😱😱😱😱😱😱😱😱',
#   1,
#   'comment'],
#  ['2025-08-12T11:37:28Z',
#   '@qornainaji9082',
#   'Shout out to my cousin, salah satu animator dan pembuat karakter di Battle of Surabaya, appreciate bgt buat karyanya 🔥. Bener2 karya anak bangsa. Bukan karya tua bangka 💀🪦.',
#   0,
#   'comment'],
#  ['2025-08-12T11:36:50Z',
#   '@Iamjustalivinghuman0101',
#   'Tegal kan Jawa tengah, kok ada 2... Tegal dan Jawa Tengah... film asal asalan',
#   1,
#   'comment'],
#  ['2025-08-12T11:34:59Z',
#   '@docHawk-de5uo',
#   'doa yang panjang buat mas vino biar kuat nonton filmnya sampai selesai',
#   0,
#   'comment'],
#  ['2025-08-12T11:34:25Z',
#   '@ihsanirsyandy6612',
#   'rill petarung, berani masukin bioskop yang jadwalnya tabrakan dengan kny',
#   0,
#   'comment'],
#  ['2025-08-12T11:32:30Z',
#   '@aidabunga-l8q',
#   'film pertama tema kebangsaan apanya? animasi the battle of Surabaya tuh shows up pertama!',
#   0,
#   'comment'],
#  ['2025-08-12T11:32:07Z',
#   '@cdwolf_second',
#   'man I hope &quot;merah putih one for all&quot; theatre is empty after the whole situation 😂',
#   0,
#   'comment'],
#  ['2025-08-12T11:31:34Z',
#   '@montianggara7789',
#   'tegal dan jawa tengah bedanya apa? tegal kan di jawa tengah...<br>gw yakin seyakinnya, perbedaan latar belakang ini cuma akan make stereotype logat dan lesapan... yg papua akan ngomong make beta, yg tegal akan dimedok-medokin, yg betawi akan ganti a jadi e (iye, kenape), yg medan akan make bah, yg tionghoa akan make haiya... just stereotype, gak akan lebih dalem dari itu.....',
#   0,
#   'comment'],
#  ['2025-08-12T11:30:15Z',
#   '@FEVERY1',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2095">34:55</a> &quot;JUMBO&quot; kemarin kok enggak didukung keknya  😌',
#   0,
#   'comment'],
#  ['2025-08-12T11:28:35Z',
#   '@fivestarlings',
#   'Ini malah mencuri uang miliaran ke 6 bilyon dn malas animasi tangan muka😢   Perbedaan besar dengan animasi indie The Amazing Circus',
#   0,
#   'comment'],
#  ['2025-08-12T11:28:34Z',
#   '@adibindrianto',
#   'orang indonesia terlalu berekspektasi terlalu tinggi',
#   0,
#   'comment'],
#  ['2025-08-12T11:28:11Z',
#   '@alvianadit4353',
#   'Baru ini gw liat dontol gak kesel, soalnya keinget ni anomali🤣',
#   0,
#   'comment'],
#  ['2025-08-12T11:23:57Z',
#   '@dendynurridmansyah6768',
#   'buat epiloge saya lebih memilih film karena mata yang melihat buriknya animasi masih bisa disembuhkan daripada telinga pecah',
#   0,
#   'comment'],
#  ['2025-08-12T11:23:45Z', '@ravorae', 'RIP VINO', 1, 'comment'],
#  ['2025-08-12T11:23:15Z',
#   '@Ken_Arc',
#   'Apakah nama karakter antagonis di film ini &quot;All for One&quot;',
#   0,
#   'comment'],
#  ['2025-08-12T11:21:10Z',
#   '@im_nooby',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3776">1:02:56</a> ada penonton letsgameout',
#   0,
#   'comment'],
#  ['2025-08-12T11:20:44Z',
#   '@nanachan7847',
#   'sorry bgt, gua anak dkv dan sorry to say tugas&quot; kami bahkan tugas akhir kami JAUH LEBIH BAGUS dari ini, kalo ga percaya silahkan buka atau cari di dokumentasi ADGI',
#   0,
#   'comment'],
#  ['2025-08-12T11:19:22Z',
#   '@FahriziArya',
#   'itu yang dibelakang dijual ga?',
#   1,
#   'comment'],
#  ['2025-08-12T11:18:46Z',
#   '@alphadesu13',
#   'Bukan ga layak masuk bioskop lagi inimah ga layak di render',
#   0,
#   'comment'],
#  ['2025-08-12T11:18:30Z',
#   '@davidsandjaya1558',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=864">14:24</a> itu anaconda dawg🙏🥀',
#   0,
#   'comment'],
#  ['2025-08-12T11:16:23Z',
#   '@ariefyusufwinata5603',
#   'sekarang sih bukan EYD tapi PUEBI.. cuman yasudah lah :&#39;v',
#   0,
#   'comment'],
#  ['2025-08-12T11:14:40Z',
#   '@666Zynx',
#   'Orang yg ngehujat animasi merah putih one for all, mungkin dia belum nonton langsung animasinya. Belum tau sebagus dan se asik apa nonton merah putih one for all. Salah satunya gw, yg awalnya gw ngira kalau merah putih one for all ga seru dan jelek malah jadi suka. Semua yg udah nonton animasi merah putih one for all pasti sependapat sama gw.\r<br>ini adalah &quot;the great Masterpiece&quot; movie all of time ketika gw menonton film ini berasa seperti masuk kedalam dunia nya yang penuh dengan keindahan yang tak terbendung, bahkan fim sekelas Disney aja Masi belum cukup untuk menandingi The great Masterpiece ini .\r<br>saya bukan sarkas tapi ini reall Base on experience, jika anda tanya kepada saya apakah worth it maka akan ku katakan bukan hanya wort it tapi Sangat sangat Teramat WORTH IT,\r<br>Sangat wajib untuk di tonton,\r<br>mau gak mau harus nonton Karena ini akan mengubah sudut pandang kehidupan manusia, ini akan menjadi langkah awal menuju peradaban Maju manusia kembali ke GOLDEN AGE era',
#   0,
#   'comment'],
#  ['2025-08-12T11:14:25Z',
#   '@elceka7274',
#   'Harusnya judul Animasi masterpiece ini adalah &quot;M4 dan M16 yg Slay&quot;',
#   1,
#   'comment'],
#  ['2025-08-12T11:13:56Z',
#   '@retrolente',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=3218">53:38</a> husnudzon dulu, trailer dan filmnya sangat beda, ternyata filmnya spek transformer',
#   0,
#   'comment'],
#  ['2025-08-12T11:13:40Z',
#   '@ericng7015',
#   'Film animasi dipaksa mesti selesai produksi dalam tiga bulan itu udah masuknya eksploitasi dan bukan buat dibanggain',
#   0,
#   'comment'],
#  ['2025-08-12T11:13:32Z',
#   '@naufala2194',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=996">16:36</a>  JANGANN.. jangan di youtube, ntar orang luar pads liat. malu',
#   0,
#   'comment'],
#  ['2025-08-12T11:10:59Z',
#   '@bngpoetra115',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2303">38:23</a> merendah dia guys padahal pernah ngisi voice over',
#   2,
#   'comment'],
#  ['2025-08-12T11:10:46Z',
#   '@rlani2290',
#   'Mending gue nonton keluarga somat sih bang, humornya juga dapet',
#   1,
#   'comment'],
#  ['2025-08-12T11:09:27Z',
#   '@asePlus26',
#   '&quot;PAKE UANG PAJAK&quot;<br>KPK HARUS USUT SIH<br><br>saya yakin RAKYAT MENDING MAKAN KERUPUK GRATIS DARI PADA NONTON FILM ITU GRATIS😂😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-12T11:09:04Z',
#   '@sherlycyusandra6587',
#   'banggg lu nyebut XXI nya kok gtu 😭😂',
#   0,
#   'comment'],
#  ['2025-08-12T11:06:41Z', '@Anichuuu2025', 'Merah putih sctv ❤', 1, 'comment'],
#  ['2025-08-12T11:06:08Z',
#   '@andhikaputra8283',
#   'Baru kali ini gua nonton TnM merinding bukan karena takut tapi karena malu.',
#   1,
#   'comment'],
#  ['2025-08-12T11:03:53Z',
#   '@didikunity3293',
#   'Btw ada yang dapet undangan nonton gratis nggak ?',
#   1,
#   'comment'],
#  ['2025-08-12T11:01:56Z',
#   '@thegreatbookofgrudges6953',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=824">13:44</a><br><a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1238">20:38</a><br><a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=1797">29:57</a><br><a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2045">34:05</a><br><a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2657">44:17</a><br><a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=2920">48:40</a> njir kayak skenario warkop',
#   0,
#   'comment'],
#  ['2025-08-12T11:00:03Z',
#   '@Batu_giok',
#   'bentar bentar kupingin ketawa gegara suara burung scarlet macaw 😭',
#   0,
#   'comment'],
#  ['2025-08-12T10:59:00Z',
#   '@retrolente',
#   'ini film kategori 45+ ga sih? dan harus bimbingan orang tua?',
#   0,
#   'comment'],
#  ['2025-08-12T10:58:37Z',
#   '@stephaniebijou',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=927">15:27</a> kalo ga salah (baca dari sinopsisnya ya) ini tuh ceritanya yg ilang &quot;Bendera Pusaka&quot; ndriii, makanya dicari2. bukan bendera biasa yg bisa beli di pasar. tanya deh sama anak paskib, pasti paham soal ini.<br><br>yaah walopun emang animasinya ancur bgt sihh, kasian banget Indonesia🤧',
#   2,
#   'comment'],
#  ['2025-08-12T15:14:23Z',
#   '@syauqifirdaus2704',
#   'Tetep aja ganjil kenapa malah nyuruh bocah-bocah dan bukan orang dewasa, misal si hansip gitu yang disuruh nyari bendera',
#   0,
#   'reply'],
#  ['2025-08-12T10:58:35Z',
#   '@gandhungwibisono5486',
#   'Beta buka gudang, benderanya hilang 😂',
#   1,
#   'comment'],
#  ['2025-08-12T10:57:52Z',
#   '@GungSatrya',
#   'Rian adriandi menangis melihat ini',
#   0,
#   'comment'],
#  ['2025-08-12T10:56:44Z',
#   '@nadnad2698',
#   'Berangkat nonton: riang gembira<br>Pulang nonton: meriang menggigil',
#   0,
#   'comment'],
#  ['2025-08-12T10:55:12Z',
#   '@IshtarSummer-nf6cg',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4163">1:09:23</a> pantes kemaren gw nonton bioskop, ga ada iklan film kayak biasanya. Langsung logo Dolby atmos<a href="UCZdmuthWjKAC-oiaoh1bfOw/pEqIX7iSKZGS-gOxvIQg"></a><a href="UCZdmuthWjKAC-oiaoh1bfOw/pEqIX7iSKZGS-gOxvIQg"></a>',
#   1,
#   'comment'],
#  ['2025-08-12T10:55:10Z',
#   '@im_nooby',
#   'klau ini tahun 90 kayanya  oke lah 3 bulan ( meski budgetnya ga munk akal)',
#   0,
#   'comment'],
#  ['2025-08-12T10:54:22Z',
#   '@UnknownGuy-y7p',
#   'Dear ibu Pertiwi 😢',
#   0,
#   'comment'],
#  ['2025-08-12T10:54:02Z',
#   '@PrimulaCalyx',
#   'Kyknya si produser mikir, klo bikin animasi itu cincai aja,  asset pun tinggal ngambil aja. Palagi ini katanya tontonan anak2. Ternyata rakyat Indonesia tidak sebodoh yg dia sangka...para ortu gen X &amp; milenial mana ridho anak2nya nonton yg kyk gitu 😅😅🤣. Ga suka pula liat bapack2 itu begitu berbangga. Gw juga gen X, selera ga kuno2 amet lah.',
#   1,
#   'comment'],
#  ['2025-08-12T10:51:10Z',
#   '@Cibludaily',
#   '<a href="http://www.youtube.com/results?search_query=%23savevino">#SAVEVINO</a>😭😭😭😭😭',
#   0,
#   'comment'],
#  ['2025-08-12T10:50:34Z',
#   '@dyahpr136',
#   'Katanya ini film targetnya anak2, tapi ponakan gw aja dikasih liat takut bjier😭',
#   0,
#   'comment'],
#  ['2025-08-12T10:50:13Z',
#   '@ayahazraboysak3727',
#   'Habis &quot;JUMBO&quot; terbitlah &quot;JEMBUT&quot; 😊',
#   0,
#   'comment'],
#  ['2025-08-12T10:48:58Z', '@idtuyul0042', 'kasian vino', 0, 'comment'],
#  ['2025-08-12T10:48:08Z',
#   '@RizalFirmansyah',
#   'kok bisa dapat sponsor BRI wkwkwkw',
#   0,
#   'comment'],
#  ['2025-08-12T10:47:49Z',
#   '@mikhaylazzarah',
#   'bendera pusaka, dicari sampe ke hutan, jatuh ke sungai tp penjahatnya mau nya dituker sama burung ? whatt ?? bang, tegal itu jawa tengah bukan sih ?',
#   0,
#   'comment'],
#  ['2025-08-12T10:45:57Z',
#   '@juannurd',
#   '<a href="https://www.youtube.com/watch?v=ORu80EfjEkg&amp;t=4353">1:12:33</a> ada tumbal proyeknya nih😂😂😂',
#   0,
#   'comment'],
#  ['2025-08-12T10:45:04Z',
#   '@gakebagiannama4401',
#   'orang macam apa si bintang mau mau aja di suruh bikin film animasi 3 bulan yang udah jelas mustahil.<br>tanpa bayaran? dan cuma dimodalin buat nraktir anak anak VO?',
#   0,
#   'comment'],
#  ['2025-08-12T10:44:33Z',
#   '@flynnk20',
#   'Bro kalian liat deh battle of surabaya udah itu keren banget',
#   0,
#   'comment'],
#  ...]

# %%
kolom = ['publishedAt', 'authorDisplayName', 'textDisplay', 'likeCount', 'type']
data = pd.DataFrame(comments, columns=kolom)

# %%
data.shape
# Out:
# (2611, 5)

# %%
data
# Out:
#                publishedAt  authorDisplayName  \
# 0     2025-08-27T06:34:43Z   @joymaradona7695
# 1     2025-08-24T23:13:27Z      @untunggratis
# 2     2025-08-24T11:07:08Z  @rezarahmaddhitya
# 3     2025-08-24T03:50:03Z      @kazutoai3940
# 4     2025-08-22T20:00:11Z      @lovendearest
# ...                    ...                ...
# 2606  2025-08-11T17:28:50Z     @d.kaliandra.r
# 2607  2025-08-11T17:27:06Z       @LuciD-id4mu
# 2608  2025-08-11T17:26:57Z     @mengsedih4432
# 2609  2025-08-11T17:25:56Z    @DekkaChannel17
# 2610  2025-08-11T17:25:46Z            @revunz
#
#                                             textDisplay  likeCount     type
# 0                             Ketawa mu jelek pisan mas          0  comment
# 1     Sebenarnya VO nya Okeh-okeh Aja, Yang Sangat D...          0  comment
# 2     <a href="https://www.youtube.com/watch?v=ORu80...          0  comment
# 3     <a href="https://www.youtube.com/watch?v=ORu80...          0  comment
# 4     <a href="https://www.youtube.com/watch?v=ORu80...          0  comment
# ...                                                 ...        ...      ...
# 2606                Geloo sejamm, kurang lama gk sih eh          0  comment
# 2607                                Selamat pagi dunia,          3  comment
# 2608                                   buset pagi bener          2  comment
# 2609                                             Mantab          1  comment
# 2610  nahkan uploadnya jam rawan<a href="UCZdmuthWjK...          3  comment
#
# [2611 rows x 5 columns]

# %%
data.describe()
# Out:
#          likeCount
# count  2611.000000
# mean      4.029491
# std      40.709214
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max    1496.000000

# %%
# https://www.youtube.com/watch?v=TzAEL-v28w4
video_id2 = 'TzAEL-v28w4'
comments2 = video_comments(video_id2)

# %%
data_2 = pd.DataFrame(comments2, columns=kolom)

# %%
data_2
# Out:
#               publishedAt     authorDisplayName  \
# 0    2025-08-25T10:19:24Z     @DibalikMindplace
# 1    2025-08-25T10:20:08Z           @KeroSengan
# 2    2025-08-25T10:34:48Z    @Ilikedarkness_911
# 3    2025-08-25T10:40:52Z    @ArthurBravefigter
# 4    2025-08-25T10:42:08Z  @FansamdRadeon7800xt
# ..                    ...                   ...
# 611  2025-08-25T12:44:40Z        @raffimohd6387
# 612  2025-08-25T13:32:18Z   @muhammadfauzan8879
# 613  2025-08-25T15:19:27Z        @tmeurahfahmii
# 614  2025-08-25T10:15:32Z             @ANTI_SAB
# 615  2025-08-25T10:15:06Z  @arsyadwianggara5163
#
#                                            textDisplay  likeCount     type
# 0    Jadi, apakah kita boleh memboikot karya orang ...        231  comment
# 1    Iya, menurutku gitu. Apalagi nyuri aset orang ...         47    reply
# 2    <a href="https://www.youtube.com/watch?v=TzAEL...         15    reply
# 3                          Merah putih.<br>Alll in one          4    reply
# 4                       All in one mereh putih <br>Waw          3    reply
# ..                                                 ...        ...      ...
# 611                        Sama aja jeleknya wkwkwkwkw          2    reply
# 612  ​@@SanKenn21 Bang kira-kira film ini Kebanyaka...          0    reply
# 613      ya logika apa yang kamu pake wahai anak muda?          0    reply
# 614                              <b>detective film</b>          0  comment
# 615                                            Pertama          0  comment
#
# [616 rows x 5 columns]

# %%
data_done = pd.concat([data, data_2], ignore_index=True)

# %%
data_done
# Out:
#                publishedAt     authorDisplayName  \
# 0     2025-08-27T06:34:43Z      @joymaradona7695
# 1     2025-08-24T23:13:27Z         @untunggratis
# 2     2025-08-24T11:07:08Z     @rezarahmaddhitya
# 3     2025-08-24T03:50:03Z         @kazutoai3940
# 4     2025-08-22T20:00:11Z         @lovendearest
# ...                    ...                   ...
# 3222  2025-08-25T12:44:40Z        @raffimohd6387
# 3223  2025-08-25T13:32:18Z   @muhammadfauzan8879
# 3224  2025-08-25T15:19:27Z        @tmeurahfahmii
# 3225  2025-08-25T10:15:32Z             @ANTI_SAB
# 3226  2025-08-25T10:15:06Z  @arsyadwianggara5163
#
#                                             textDisplay  likeCount     type
# 0                             Ketawa mu jelek pisan mas          0  comment
# 1     Sebenarnya VO nya Okeh-okeh Aja, Yang Sangat D...          0  comment
# 2     <a href="https://www.youtube.com/watch?v=ORu80...          0  comment
# 3     <a href="https://www.youtube.com/watch?v=ORu80...          0  comment
# 4     <a href="https://www.youtube.com/watch?v=ORu80...          0  comment
# ...                                                 ...        ...      ...
# 3222                        Sama aja jeleknya wkwkwkwkw          2    reply
# 3223  ​@@SanKenn21 Bang kira-kira film ini Kebanyaka...          0    reply
# 3224      ya logika apa yang kamu pake wahai anak muda?          0    reply
# 3225                              <b>detective film</b>          0  comment
# 3226                                            Pertama          0  comment
#
# [3227 rows x 5 columns]

# %%
# https://www.youtube.com/watch?v=6jdG2WQEgyI
video_id3 = '6jdG2WQEgyI'
comments3 = video_comments(video_id3)

# %%
data_3 = pd.DataFrame(comments3, columns=kolom)

# %%
data_3
# Out:
#                publishedAt                authorDisplayName  \
# 0     2025-08-28T08:45:34Z                    @SyafeQah1990
# 1     2025-08-28T08:29:35Z                  @HusnaNurul-m6h
# 2     2025-08-28T08:14:10Z                       @AlvinoAWP
# 3     2025-08-28T07:56:15Z               @arkanpradipta8934
# 4     2025-08-28T07:50:36Z  @galangadimaskhrisnaherlamb4053
# ...                    ...                              ...
# 4751  2025-08-11T08:57:24Z                  @prod.starlight
# 4752  2025-08-15T09:15:28Z                    @dikaalvin657
# 4753  2025-08-15T23:23:43Z              @matthewbrealey2026
# 4754  2025-08-09T04:07:03Z               @robbycarnando4512
# 4755  2025-08-09T04:04:52Z                @GenerasimudaMuda
#
#                                             textDisplay  likeCount     type
# 0                       Cartoon ni masuk pawagam...??..          0  comment
# 1     ini yg katanya film mengeluarkan dan sampe mil...          0  comment
# 2                         Burung.nya.suara.monyet.cok🗿🗿          0  comment
# 3     <a href="https://www.youtube.com/watch?v=6jdG2...          0  comment
# 4         bahkan jurasik park 1993 lebih bagus dari ini          1  comment
# ...                                                 ...        ...      ...
# 4751  ​@@JustAnOrd1naryMankok XXI gaada trailer sih?...          6    reply
# 4752                  Kalau fulus<br>Pasti mulus<br>😂😂😂          2    reply
# 4753                  @@prod.starlight masuk di XXI loh          0    reply
# 4754                   Pengisi suara ny spa aj yahhh...          1  comment
# 4755                                              😂😂😂😅😅          2  comment
#
# [4756 rows x 5 columns]

# %%
nama_file_csv = "../data/smerahputih_oneforall.csv"
data_3.to_csv(nama_file_csv, index=False, encoding='utf-8')
